# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("ROBOFLOW_API_KEY")
workspace = os.getenv("WORKSPACE")

# %%
from roboflow import Roboflow
rf = Roboflow(api_key=api_key)
project = rf.workspace(workspace).project("Doom Enemy Classifier")
dataset = project.version(1).download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# RoboflowError                             Traceback (most recent call last)
# Cell In[7], line 3
#       1 from roboflow import Roboflow
#       2 rf = Roboflow(api_key=api_key)
# ----> 3 project = rf.workspace("jemmanuelss-outlook-com").project("Doom Enemy Classifier")
#       4 dataset = project.version(1).download("yolov11")
#
# File ~/DeVeLoP/AI-ML/doom-mlg-ai/venv/lib/python3.14/site-packages/roboflow/core/workspace.py:99, in Workspace.project(self, project_id)
#      96 if "/" in project_id:
#      97     raise RuntimeError(f"The {project_id} project is not available in this ({self.url}) workspace")
# ---> 99 dataset_info = rfapi.get_project(self.__api_key, self.url, project_id)
#     100 dataset_info = dataset_info["project"]
#     102 return Project(self.__api_key, dataset_info, self.model_format)
#
# File ~/DeVeLoP/AI-ML/doom-mlg-ai/venv/lib/python3.14/site-packages/roboflow/adapters/rfapi.py:57, in get_project(api_key, workspace_url, project_url)
#      55 response = requests.get(url)
#      56 if response.status_code != 200:
# ---> 57     raise RoboflowError(response.text)
#      58 result = response.json()
#      59 return result
#
# RoboflowError: {"error":{"message":"Unsupported request. `GET /jemmanuelss-outlook-com/Doom%20Enemy%20Classifier` does not exist or cannot be loaded due to missing permissions.","type":"GraphMethodException","hint":"You can see your active workspace by issuing a GET request to `/` with your `api_key`."}}
